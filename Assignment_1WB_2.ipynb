# %%
import pandas as pd
df = pd.read_excel("AFN01.xls" , nrows=10)
df
# Out:
#         Areaname  STCOU  AFN110197F  AFN110197D  AFN110197N1  AFN110197N2  \
# 0  UNITED STATES      0           0      545068            0            0
# 1        ALABAMA   1000           0        6955            0            0
# 2    Autauga, AL   1001           0          50            0            0
# 3    Baldwin, AL   1003           0         303            0            0
# 4    Barbour, AL   1005           0          42            0            0
# 5       Bibb, AL   1007           0          12            0            0
# 6     Blount, AL   1009           0          42            0            0
# 7    Bullock, AL   1011           0          12            0            0
# 8     Butler, AL   1013           0          31            0            0
# 9    Calhoun, AL   1015           0         185            0            0
#
#    AFN110202F  AFN110202D  AFN110202N1  AFN110202N2  ...  AFN130202N1  \
# 0           0      565590            0            0  ...            0
# ...
